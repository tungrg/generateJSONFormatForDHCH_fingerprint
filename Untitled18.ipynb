# %% [markdown]
# <a href="https://colab.research.google.com/github/tungrg/generateJSONFormatForDHCH_fingerprint/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://drive.google.com/uc?id=1_i4ci3YCGyoN606ZuyvprgQzNqpC_ZBG > dhcp_fingerprints.conf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_i4ci3YCGyoN606ZuyvprgQzNqpC_ZBG
# To: /content/dhcp_fingerprints.conf
# 100% 29.0k/29.0k [00:00<00:00, 35.6MB/s]

# %%
import json
import re

# %%
file1 = open('/content/dhcp_fingerprints.conf', 'r')
text = file1.readlines()

# %%
#class for OS
class OS:
  def __init__(self, name, range):
    self.name = name
    self.range = range

# %%
#get range of os for example: "members=100-199" -> (100,199)
def parseListRange(rangeListToParse):
  rangeListTemp = rangeListToParse.rsplit(",")
  rangeList = []
  for i in rangeListTemp:
    rangeList.append((int(i.rsplit("-")[0]),int(i.rsplit("-")[-1])))
  return rangeList

# %%
#parse to get each line in the file
def parseOS(Lines):
  index = 0;
  listOS = []
  while(index < len(Lines)):
    if("[class" in Lines[index]):
      index+=1
      name = Lines[index].strip().rsplit("=")[1]
      index+=1
      range = Lines[index].rsplit("=")[1]
      rangeList = parseListRange(range)
      operatingSystem = OS(name, rangeList);
      listOS.append(operatingSystem)
    index+=1
    if ("[os" in Lines[index]):
      break
  return index, listOS

# %%
indexing, OSlist = parseOS(text)

# %%
#fingerprint from decimal to heximal
def parseDecimalToHex(decimalList):
  result = ""
  for i in decimalList.rsplit(","):
    result+= format(int(i), '02x')
  return result

# %%
#class for child os
class ChildOS(OS):
  def __init__(self, name, id, vendorList, fingerprint):
    self.name = name
    self.id = id
    self.vendorList = vendorList
    self.fingerprint = fingerprint

# %%
#parse child os
def ParseChildOS(Lines, index):
  OSChildList = []
  while(index < len(Lines)):
    if("[os" in Lines[index]):
      id = int(re.findall(r'\d+', Lines[index])[0])
      index +=1
    if ('description' in Lines[index]):
      name = Lines[index].strip().rsplit("=")[1]
      index +=1
    vendorIDList = []
    if ("vendor_id" in Lines[index]):
      index+=1
      while("EOT" not in Lines[index]):
        vendorIDList.append(Lines[index].strip())
        index+=1
      index+=1
    fingerprintsList = []
    if("fingerprints" in Lines[index]):
      index+=1
      fingerprint = ""
      while("EOT" not in Lines[index]):
        fingerprint = parseDecimalToHex(Lines[index])
        fingerprintsList.append(fingerprint)
        index+=1
      index +=1
      OSChildList.append(ChildOS(name,id, vendorIDList, fingerprintsList))
    index+=1
  return OSChildList

# %%
#get the list of all child os from the text file
OSChildList = ParseChildOS(text,indexing)

# %%
#get class of child os from its id
def getClassOS(id, OSlistAug):
  classOS = []
  for i in OSlistAug:
    for j in i.range:
      if id >= j[0] and id <= j[1]:
        classOS.append(i.name)
  return classOS

# %%
OSChildList[0].name
# Out:
# 'Microsoft Windows XP'

# %%
#save the result into a dictionary
result = {}
for i in OSChildList:
  if not i.vendorList:
    tempDictResult = {"description": i.name, "fingerprint": i.fingerprint}
  else:
    tempDictResult = {"description": i.name, "vendor_id": i.vendorList, "fingerprint": i.fingerprint}
  idResult = getClassOS(i.id, OSlist)
  for j in idResult:
    if j in result:
      result[j].append(tempDictResult)
    else:
      result[j] = [tempDictResult]

# %%
result
# Out:
# {'Windows': [{'description': 'Microsoft Windows XP',
#    'vendor_id': ['MSFT 5.0'],
#    'fingerprint': ['010f03062c2e2f1f21f92b',
#     '010f03062c2e2f1f21f92bfc',
#     '010f03062c2e2f1f21f92bfc0c',
#     '0f03062c2e2f1f21f92b',
#     '0f03062c2e2f1f21f92bfc',
#     '0f03062c2e2f1f21f92bfc0c',
#     '1c02030f060c2c2f']},
#   {'description': 'Microsoft Windows 2000',
#    'vendor_id': ['MSFT 5.0', 'MSFT'],
#    'fingerprint': ['010f03062c2e2f1f212b',
#     '010f03062c2e2f1f212bfc',
#     '010f03062c2e2f1f212bfc0c',
#     '0f03062c2e2f1f212b',
#     '0f03062c2e2f1f212bfc']},
#   {'description': 'Microsoft Windows ME',
#    'vendor_id': ['MS', 'MSFT'],
#    'fingerprint': ['010f03062c2e2f1f212b4d', '0f03062c2e2f1f212b4d']},
#   {'description': 'Microsoft Windows 98',
#    'vendor_id': ['MSFT 98', 'MSFT'],
#    'fingerprint': ['0103060f2c2e2f39']},
#   {'description': 'Microsoft Windows 95', 'fingerprint': ['01030f062c2e2f']},
#   {'description': 'Microsoft Windows NT 4',
#    'fingerprint': ['010203060c0f1a1c555657582c2d2e2f46454e4f',
#     '010f032c2e2f06']},
#   {'description': 'Microsoft Windows 98SE',
#    'vendor_id': ['MSFT 5.0'],
#    'fingerprint': ['0f03062c2e2f2b4d',
#     '010f03062c2e2f2b4d',
#     '0f03062c2e2f2b4dfc',
#     '010f03062c2e2f2b4dfc']},
#   {'description': 'Microsoft Windows Vista/7 or Server 2008',
#    'vendor_id': ['MSFT 5.0'],
#    'fingerprint': ['010f03062c2e2f1f2179f92b', '010f03062c2e2f1f2179f92bfc']},
#   {'description': 'Microsoft Windows 8',
#    'fingerprint': ['010f03062c2e2f1f2179f9fc2b']}],
#  'Dead OSes': [{'description': 'Microsoft Windows ME',
#    'vendor_id': ['MS', 'MSFT'],
#    'fingerprint': ['010f03062c2e2f1f212b4d', '0f03062c2e2f1f212b4d']},
#   {'description': 'Microsoft Windows 98',
#    'vendor_id': ['MSFT 98', 'MSFT'],
#    'fingerprint': ['0103060f2c2e2f39']},
#   {'description': 'Microsoft Windows 95', 'fingerprint': ['01030f062c2e2f']},
#   {'description': 'Microsoft Windows NT 4',
#    'fingerprint': ['010203060c0f1a1c555657582c2d2e2f46454e4f',
#     '010f032c2e2f06']},
#   {'description': 'Microsoft Windows 98SE',
#    'vendor_id': ['MSFT 5.0'],
#    'fingerprint': ['0f03062c2e2f2b4d',
#     '010f03062c2e2f2b4d',
#     '0f03062c2e2f2b4dfc',
#     '010f03062c2e2f2b4dfc']},
#   {'description': 'OS/2 Warp', 'fingerprint': ['0103060f1c21']},
#   {'description': 'BeOS', 'fingerprint': ['0103060f0c13']}],
#  'Macintosh': [{'description': 'Mac OS X',
#    'fingerprint': ['0103060f70714e4f5f',
#     '0103060f70714e4f5ffc',
#     '03060f70714e4f5ffc',
#     '03060f70714e4f5f',
#     '03060f70714e4f5f2c2f',
#     '0103060f70714e4f5f2c2f',
#     '0103060f70714e4f',
#     '0103060f7770714e4f5ffc',
#     '03060f70714e4f5ffc2c2f',
#     '0103060f70714e4f5ffc2c2f',
#     '01030c060f70714e4f',
#     '3c2b',
#     '2b3c',
#     '0103060f775ffc2c2e2f',
#     '0103060f775ffc2c2e2f65']},
#   {'description': 'Mac OS 9',
#    'fingerprint': ['0103060f212a2c2d2e2f4546474a4e4f']},
#   {'description': 'Mac OS X Lion', 'fingerprint': ['0103060f775ffc2c2e']}],
#  'VoIP Phones/Adapters': [{'description': 'Cisco IP Phone',
#    'vendor_id': ['Cisco Systems, Inc. IP Phone',
#     'Cisco Systems, Inc. IP Phone 7905',
#     'Cisco Systems, Inc. IP Phone 7912',
#     'Cisco Systems, Inc. IP Phone CP-7960',
#     'Cisco Systems, Inc. IP Phone CP-7960G'],
#    'fingerprint': ['014206030f9623',
#     '014206030f962397',
#     '0103060f2a4296',
#     '011c42060f032396',
#     '0103060f23423396',
#     '0103060f2a423396',
#     '0103060c0f2a4296',
#     '0103060f234296',
#     '0103060c0f1c2a429596',
#     '060301420f96']},
#   {'description': 'Avaya IP Phone',
#    'fingerprint': ['0103060f42452bb0',
#     '010307060f42452bb0',
#     '011c03060f2af2',
#     '011c03060f2a2bb042']},
#   {'description': 'BATM VoIP Adapter', 'fingerprint': ['0103060f0c']},
#   {'description': 'Linksys PAP VoIP', 'fingerprint': ['01032a06070f3a3b42']},
#   {'description': 'Mediatrix VoIP Adapter', 'fingerprint': ['0103060c0f2a2b']},
#   {'description': 'Uniden DTA VoIP Adapater', 'fingerprint': ['010203060f2a']},
#   {'description': 'UniData IP Phone',
#    'fingerprint': ['36333a3b0103060f1c8b', '36333a3b0103060f1c8b022a42']},
#   {'description': 'Sunrocket VoIP Gizmo',
#    'vendor_id': ['MTA6328R'],
#    'fingerprint': ['0301060c0f43422b']},
#   {'description': 'Sipura VoIP Adaptor',
#    'fingerprint': ['010f03062c2e2f42', '01032a06070f3a3b2c42']},
#   {'description': 'Clipcomm IP Phone',
#    'fingerprint': ['0103060f2c2e2f1f212b']},
#   {'description': 'Nortel IP Phone',
#    'fingerprint': ['011c0103',
#     '011c03',
#     '333a3b01032b80909dbffb',
#     '011c01032b8083909dbcbfcddbdfe8f7fb3a3b',
#     '011c032b8083909dbcbfcddbdfe8f7fb3a3b',
#     '011c032b8083909dbcbfcddbdfe8f7fb3a3b42',
#     '011c032b8083909dbcbfcddbdfe8f7fb3a3b42060f',
#     '011c032b8083909dbcbfcddbdfe0e3e6e8ebeef1f4f7f9fbfe3a3b42',
#     '011c032b8083909dbcbfcddbdfe0e3e6e8ebeef1f4f7f9fbfe3a3b42060f']},
#   {'description': 'ZyXEL WiFi Phone', 'fingerprint': ['010306420f']},
#   {'description': 'UTStarcom F3000', 'fingerprint': ['01060f032b']},
#   {'description': 'ShoreTel IP Phone', 'fingerprint': ['011c9c0403422a']},
#   {'description': 'Siemens OpenStage IP Phones',
#    'fingerprint': ['010203060c0f1c212a2b78']},
#   {'description': 'Siemens optiPoint WL2 Professional',
#    'fingerprint': ['010203060c0f1c2a2b78']},
#   {'description': 'Siemens optiPoint 410/420',
#    'fingerprint': ['011c2b03', '011c03060f212a022b', '011c03060f212a022b78']},
#   {'description': 'Alcatel Advanced Reflex IP Phone',
#    'fingerprint': ['011c363a3b3c2b03']},
#   {'description': 'Alcatel IP Touch 8 Series Phones',
#    'fingerprint': ['01031c2b3a3b']},
#   {'description': 'Cisco/Linksys SPA series IP Phone',
#    'fingerprint': ['01032a06070f3a3b2c429697',
#     '01032a06070f3a3b2c42960297',
#     '01032a06070f3a3b42029697a09f']},
#   {'description': 'Siemens optiPoint 150 S', 'fingerprint': ['0103060c0f42']},
#   {'description': 'Mitel IP Phone',
#    'fingerprint': ['0103060c2a2c33363a3b80427881828384858687e08a7d2b']},
#   {'description': 'Polycom Conference IP Phone',
#    'fingerprint': ['0103060f2a2b2c2e2f77',
#     '011c42060f03232b8083909dbcbfcddbdfe8f7fb']},
#   {'description': 'Polycom SoundPoint IP 430',
#    'fingerprint': ['011c4203042a02060f']},
#   {'description': 'Snom VoIP solutions',
#    'fingerprint': ['0103060c0f2a424378']},
#   {'description': 'Aastra VoIP',
#    'fingerprint': ['0103062a2b0242',
#     '0103062a2b429fa0',
#     '0103062a2b02429fa0',
#     '011c0103062a42']},
#   {'description': 'Nortel IP Phone Model 1535',
#    'fingerprint': ['0103060c0f11171c1d1f2128292a42',
#     '0103060c0f11171c1d1f2128292a424896']},
#   {'description': 'Polycom SoundPoint IP 450',
#    'fingerprint': ['011ca04203042a02060f']},
#   {'description': 'Polycom SoundStation IP 6000',
#    'fingerprint': ['01030fa0420304362a02060f']},
#   {'description': 'Polycom SoundPoint IP 301',
#    'fingerprint': ['011c0342042a02060f']},
#   {'description': 'GrandStream HandyTone 503 ATA',
#    'fingerprint': ['0103060c0f1c42']},
#   {'description': 'Unidentified Polycom',
#    'fingerprint': ['011c42060f0323b0', '01030ff204362a0206']},
#   {'description': 'MagicJack Plus', 'fingerprint': ['36333a3b0103060f1c']},
#   {'description': 'Cisco ATA 186', 'fingerprint': ['0103060c0f2a4296']}],
#  'Routers and APs': [{'description': 'Cisco Wireless Access Point',
#    'vendor_id': ['Airespace.AP120'],
#    'fingerprint': ['011c03060f430407',
#     '011c03060f4304',
#     '011c03060f2c',
#     '011c032b',
#     '01060f2c0321962b',
#     '01060f2c030721962b',
#     '0142060f2c034321962b',
#     '0142060f2c03430c21962b',
#     '0142060f2c03430c21962b7d']},
#   {'description': 'Compex Wireless Access Point',
#    'fingerprint': ['01030f062b4d']},
#   {'description': 'Cisco/Linksys Router',
#    'fingerprint': ['0103060c0f1c',
#     '0103060f1c36',
#     '011c02030f060c0407171a2b323336373c3d',
#     '011c02030f060c0407171a2b323336373c48',
#     '0103060c0f2c2e2f',
#     '010f03062c2e2f',
#     '010f03062c2e2f0103060f2c2e2f',
#     '010f03062c2e2f420103060f2c2e2f',
#     '0103060c0f1c2c',
#     '0f03062c2e2f',
#     '060301',
#     '0103060c0f1c2c21f9',
#     '0103060c0f1c28292a79']},
#   {'description': 'Netgear Router',
#    'fingerprint': ['0103060c0f1c2179',
#     '03060f',
#     '0301060f',
#     '0301060f0c',
#     '017903060c0f1c21',
#     '017903060c0f1c212b',
#     '0103060c0f1c212c79',
#     '0103060c0f1c212c79f9']},
#   {'description': 'OEMed Wireless Router', 'fingerprint': ['0103060f']},
#   {'description': 'Apple Airport',
#    'fingerprint': ['1c03060f', '011c03060f', '0102030f060c2c']},
#   {'description': 'Symbol Wireless Access Point',
#    'vendor_id': ['S24AP'],
#    'fingerprint': ['0103060c0f2b42438081828384858687']},
#   {'description': 'Gemtek Wireless Router',
#    'fingerprint': ['0103060f2b2c2e2f',
#     '011c02030f060c0407171a2b323336373c3d48']},
#   {'description': 'D-Link Wireless Router',
#    'fingerprint': ['0103060c0f42454643',
#     '0103060c0f1c28292a2c2e2f',
#     '0103060c0f1c2128292a2c2e2f',
#     '0103060c0f1c2128292a2c2e2f79f9',
#     '0103062c0f2e2f',
#     '0103060c0f1c2c2e2f',
#     '0103060f212c2e2f79']},
#   {'description': '2Wire Residential Gateway',
#    'fingerprint': ['010203060f582a2c2e2f']},
#   {'description': 'Motorola Router', 'fingerprint': ['011c01030604']},
#   {'description': 'Buffalo Wireless AP',
#    'fingerprint': ['0103060c0f171c1d1f2128292a2c']},
#   {'description': 'Bluesocket BSC', 'fingerprint': ['011c030f060c2c']},
#   {'description': 'DD-WRT Router', 'fingerprint': ['0103060c0f1c28292a']},
#   {'description': 'Trendnet Access Point',
#    'fingerprint': ['011c0605032c0f', '0605032c0f']},
#   {'description': 'TP-Link Wireless LAN Router',
#    'fingerprint': ['01032b2c2e2f06',
#     '0103060c0f111c2a',
#     '011c032b2c2e2f06',
#     '01032b2c2e2f062179',
#     '01032b2c2e2f062179f9',
#     '0103060f212b2c2e2f79',
#     '0103060f212b2c2e2f79f9']},
#   {'description': 'Ruckus Wireless', 'fingerprint': ['010203060c0f1c2a2b2c']},
#   {'description': 'Enterasys or Trapeze Wireless Access Point',
#    'fingerprint': ['010f03062b']},
#   {'description': 'Enterasys HiPath Wireless Access Point',
#    'fingerprint': ['011c03060f0c']},
#   {'description': 'Quanta Microsystems Router',
#    'fingerprint': ['03161701182123060f']},
#   {'description': 'HP ProCurve Access Point',
#    'fingerprint': ['011c02030f060c2b']},
#   {'description': 'HP ProCurve Controller',
#    'fingerprint': ['011c02030f060c2c']},
#   {'description': 'Aruba Access Point',
#    'fingerprint': ['010304060c0f1c2a2b3c',
#     '0103060c0f042b2c3c2a1c',
#     '0103060c0f112b3c']},
#   {'description': 'Trendnet Wireless Router',
#    'fingerprint': ['01f903060c0f1c2128292a2c']},
#   {'description': 'Belkin Wireless Router',
#    'fingerprint': ['0301060f79', '01030c172c2f', '0103060c0f1c212c']},
#   {'description': 'MikroTik (RouterOS)', 'fingerprint': ['01790321062a']},
#   {'description': 'Freebox Wireless Router',
#    'fingerprint': ['0103060f333a3bff']},
#   {'description': 'AeroHive Hive Access Points',
#    'fingerprint': ['010306070c0f1c28292ae1e2e3e4']},
#   {'description': 'Tenda Wireless Router',
#    'fingerprint': ['0103060f1f212b2c2e2ff9']},
#   {'description': 'Zioncom Wireless Router',
#    'fingerprint': ['0103060a0c0e0f1c28292a57']}],
#  'Linux': [{'description': 'Debian-based Linux',
#    'fingerprint': ['011c02030f060c',
#     '011c02030f060c2a',
#     '03060f1c0c07092a3031',
#     '011c02030f060c2c2f',
#     '011c02030f060c2c2f1a',
#     '011c02030f06770c2c2f1a',
#     '011c02030f06770c']},
#   {'description': 'Generic Linux',
#    'fingerprint': ['03060c0f11171c1d1f2128292a77',
#     '0103060c0f171c1d1f2128292a',
#     '03060c0f11171c1d1f2128292a0907c82c',
#     '0103060c0f171c1d1f2128292a0907c82c',
#     '011c02030f060c79f9fc2a',
#     '0103060c0f1c28292a77']},
#   {'description': 'SUSE Linux/Novell Desktop',
#    'fingerprint': ['0103060c0f11171c1d1f2128292a0907c82c',
#     '0103060c0f11171c1d1f2128292a09072c2d2e2f',
#     '0103060c0f11171c1d1f2128292a09072c2d2e2f77',
#     '011c02030f060c2829']},
#   {'description': 'RedHat/Fedora-based Linux',
#    'fingerprint': ['011c02030f060c28292a',
#     '1c02030f060c28292a',
#     '011c02030f060c28292a1a77',
#     '011c02030f060c28292a1a']},
#   {'description': 'Gentoo Linux',
#    'fingerprint': ['0103060c0f11171c1d1f2128292a',
#     '0103060c0f11171c1d1f2128292a77',
#     '3a3b011c7921030c770f0628292a1a',
#     '01792103060c0f1c28292a333a3b77',
#     '01792103060c0f1a1c2a33363a3b77']},
#   {'description': 'Ubuntu/Debian 5/Knoppix 6',
#    'fingerprint': ['011c02030f06770c2c2f1a79', '011c02030f06770c2c2f1a792a']},
#   {'description': 'FortiOS', 'fingerprint': ['010203060c0f1c282a']},
#   {'description': 'Puppy Linux 4.x',
#    'fingerprint': ['3a3b011c7921030c770f0628292a1a1178']},
#   {'description': 'Meego Netbook', 'fingerprint': ['fc032a0f06010c']},
#   {'description': 'Ubuntu Server 10.04 LTS',
#    'fingerprint': ['3a3b011c7921030c770f061a1178']},
#   {'description': 'Suse Linux Enterprise Desktop 11',
#    'fingerprint': ['011c031a0c0f0628295755562c2d2e2f2a']},
#   {'description': 'Ubuntu 11.04',
#    'fingerprint': ['011c02030f06770c2c2f1a792a79f9fc2a']},
#   {'description': 'Fedora 14 based distro',
#    'fingerprint': ['011c02790f060c28292a1a7703']},
#   {'description': 'Chrome OS',
#    'fingerprint': ['01792103060c0f1a1c33363a3b77']},
#   {'description': 'Fedora 15 or 16 based distro',
#    'fingerprint': ['011c02790f060c28292a1a770379f9fc2a']}],
#  'Gaming Consoles': [{'description': 'Xbox', 'fingerprint': ['0306']},
#   {'description': 'Xbox 360', 'fingerprint': ['010306']},
#   {'description': 'Playstation 2', 'fingerprint': ['030f06', '01030f06']},
#   {'description': 'Gamecube', 'fingerprint': ['03061a1c3a3b']},
#   {'description': 'Wii', 'fingerprint': ['0103060c0f1c213a3b']},
#   {'description': 'Playstation 3 or Playstation Portable (PSP)',
#    'fingerprint': ['01031c060f']}],
#  'Home Audio/Video Equipment': [{'description': 'TiVo',
#    'fingerprint': ['1c02030f060c']},
#   {'description': 'Replay TV', 'fingerprint': ['0102030407060f', '011c']},
#   {'description': 'Amino Aminet Set Top Box',
#    'fingerprint': ['010203060c0f11171c1d1f2128292a2b',
#     '0103060c0f11171c1d1f2128292a2b']},
#   {'description': 'Slingbox', 'fingerprint': ['0103060f2c2e2f']},
#   {'description': 'Motorola NIM100', 'fingerprint': ['0103060f173336']},
#   {'description': 'Sony player', 'fingerprint': ['0103060f33']},
#   {'description': 'Panasonic G20 Television',
#    'fingerprint': ['3a3b060f33360103']}],
#  'Printers': [{'description': 'HP Printer',
#    'fingerprint': ['0103072c33363a3b0c0f9012',
#     '01032c06070c0f16363a3b451290',
#     '032c06070c0f16363a3b451290',
#     '032c0651070c0f16363a3b451290',
#     '03072c33363a3b0c0f9012',
#     '01032c06070c0f16363a3b1290',
#     '01032c0651070c0f16363a3b451290',
#     '0103072c33363a3b0c9012',
#     '0603010f42430d0c',
#     '01032c06070c0f16363a3b45129077',
#     '0603010f42430d2c0c',
#     '0603010f42430d2c0c51',
#     '01032c06070c0f16363a3b45122b779a',
#     '01032c06070cfc0f16363a3b45122b7751999a',
#     '01032c06070c0f16363a3b45122b77',
#     '0603010f0c42430d2c',
#     '01032c06070c0f16363a3b45122b',
#     '0603010f42430d',
#     '03010f2c0c',
#     '0603010f2c0c']},
#   {'description': 'Canon Printer',
#    'fingerprint': ['03060f2c2f', '0103060f2c2f', '01030c17060f']},
#   {'description': 'Xerox Printer',
#    'fingerprint': ['3301033a3b0c2c36060f90',
#     '011c030f060c2c4e4f',
#     '011c030f060c2c4e4f4243',
#     '01031c3a3b060f4e4f2c2e4542430c',
#     '0c',
#     '01031c060f2c2e450c51',
#     '01031c3a3b060f4e4f2c2e450c51',
#     '01031c3a3b060f4e4f2c2e4542430c51',
#     '011c033a3b060f4e4f2c2e457442430c',
#     '011c033a3b060f4e4f0c2c2e45744243',
#     '011c030f060c2c4e4f022a',
#     '010306070c0f12171a2c2e33363a3b4e4f',
#     '011c033a3b060f4e4f0c2a2c2e45744243',
#     '011c033a3b060f4e4f2a2c2e457442430c',
#     '010203060c0f1a1c555657582c2d2e2f46454e4f78']},
#   {'description': 'Dell Printer',
#    'fingerprint': ['010203060c0f1a1c582c2d2e2f46454e4f']},
#   {'description': 'Brother Printer',
#    'fingerprint': ['0103060c0f1c2a282c2e',
#     '0603010f42430d0c2c',
#     '010203060c0f1a1c555657582c2d2e2f',
#     '0603010f42430d0c2c022a']},
#   {'description': 'Tally Printer', 'fingerprint': ['0103063a3b2c2e2f']},
#   {'description': 'Kyocera Printer',
#    'fingerprint': ['01030c060f172c2f',
#     '01030c17060f2c2f',
#     '01030f062c',
#     '01792103060f1c28292a333a3b77',
#     '0103060f1c2128292a333a3b7779']},
#   {'description': 'Epson Printer', 'fingerprint': ['0103060c0f1c2a28']},
#   {'description': 'Lexmark Printer',
#    'fingerprint': ['0103060c0f1c2a282617252c27131a',
#     '0103042a06070c0f1a2c33363a3bbe',
#     '0103070c1a2c33363a3bbe',
#     '0103070c1a2c33363a3b',
#     '01032a0406070c0f1a2c33363a3bbe',
#     '01032a0406070c1a2c33363a3bbe',
#     '01032a0406070c0f1a33363a3b']},
#   {'description': 'Trendnet Printserver', 'fingerprint': ['0103']},
#   {'description': 'Generic Printer',
#    'fingerprint': ['010306070c0f12171a2c2e33363a3b4e4f51']},
#   {'description': 'Toshiba Multifunction Printer',
#    'fingerprint': ['0103062c0c0f0445462a']},
#   {'description': 'Ricoh Multifunction Printer',
#    'fingerprint': ['0103060f1c2c2f', '0103060c0f1c2c2f']},
#   {'description': 'Konica Minolta Multifunction Printer',
#    'fingerprint': ['0103060f2c2e', '0103060f2c', '0103062c2e', '010317060f']},
#   {'description': 'Zebra Printer', 'fingerprint': ['03161701182123060f2c0b']}],
#  'Switches': [{'description': 'Cisco Catalyst 29xx',
#    'vendor_id': ['docsis1.0'],
#    'fingerprint': ['0142060343', '01420603430c96', '0142060343962b']},
#   {'description': 'Cisco Catalyst 35xx',
#    'fingerprint': ['01060f2c0321', '01060f2c34']},
#   {'description': 'HP ProCurve',
#    'fingerprint': ['0103041743', '01030417', '0103042b', '010304174342']},
#   {'description': 'Enterasys SecureStacks', 'fingerprint': ['0301']},
#   {'description': 'Cisco Small Business',
#    'fingerprint': ['010342433681968384060f64']},
#   {'description': '3Com Switches', 'fingerprint': ['0103060f1b']},
#   {'description': 'HP ProCurve 1800-8G', 'fingerprint': ['01030c']},
#   {'description': 'HP ProCurve 3500yl', 'fingerprint': ['0103041743422b']},
#   {'description': '3Com 4400 SE Switch',
#    'fingerprint': ['010636452a320403330c74']}],
#  'Storage Devices': [{'description': 'Hotway LanDrive',
#    'fingerprint': ['0103060f1c']},
#   {'description': 'LaCie NAS', 'fingerprint': ['0103060c0f1c2a']},
#   {'description': 'Xyratex NAS', 'fingerprint': ['010603']},
#   {'description': 'Synology NAS',
#    'fingerprint': ['0103060c0f11171c1d1f2128292a2c']}],
#  'Smartphones/PDAs/Tablets': [{'description': 'Nokia Internet Tablet (udhcpc client)',
#    'fingerprint': ['0103060c0f111c28292a', '0103061c']},
#   {'description': 'RIM BlackBerry', 'fingerprint': ['380601030f']},
#   {'description': 'Apple iPod, iPhone or iPad',
#    'fingerprint': ['0103060f774e4f5ffc',
#     '0103060f77fc',
#     '0103060f77fc2ed05c',
#     '0103060f77fc43340d']},
#   {'description': 'HTC Android', 'fingerprint': ['017921031c333a3b']},
#   {'description': 'Symbian OS',
#    'fingerprint': ['0c060f01031c78', '0c060f01031c7877']},
#   {'description': 'Sony Ericsson Android',
#    'fingerprint': ['0103060c0f1c21333a3b7779']},
#   {'description': 'Apple iPod', 'fingerprint': ['010f0306']},
#   {'description': 'Samsung S8000',
#    'fingerprint': ['0102030405060708090c0d0f1011171a1c2a2c32333536384243']},
#   {'description': 'Samsung S8500',
#    'fingerprint': ['010305060c0d0f11171c2a32333536384243',
#     '01030506200d0f11171c2a32333536384243',
#     '01030506310d0f11171c2a32333536384243']},
#   {'description': 'Sony Ericsson W800i', 'fingerprint': ['01030678']},
#   {'description': 'LG BL40', 'fingerprint': ['36330601031a0f78']},
#   {'description': 'Generic Android',
#    'fingerprint': ['01792103061c333a3b',
#     '0103061c21333a3b79',
#     '01792103060f1c333a3b77',
#     '01792103060c0f1c333a3b77']},
#   {'description': 'Samsung Android',
#    'fingerprint': ['01792103060f1c333a3b',
#     '0103060f1c21333a3b79',
#     '0603010f0c2a',
#     '012103060f1c333a3b']},
#   {'description': 'Palm OS', 'fingerprint': ['0103060f2c2e2f4243']},
#   {'description': 'Sharp Phone', 'fingerprint': ['36330601030f78']},
#   {'description': 'Android Tablet', 'fingerprint': ['012103061c333a3b']},
#   {'description': 'Unknown Android', 'fingerprint': ['01792103061c2a333a3b']},
#   {'description': 'Motorola Android',
#    'fingerprint': ['01792103060f1c2c333a3b77']},
#   {'description': 'Vizio Android Tablet',
#    'fingerprint': ['01792103060c0f1c2a333a3b77']},
#   {'description': 'Samsung SGH T528g', 'fingerprint': ['0103060c333a3b']}],
#  'Monitoring Devices': [{'description': 'NetBotz WallBotz 400C',
#    'fingerprint': ['0103060f0c4546582a']},
#   {'description': 'HP iLO Agent',
#    'fingerprint': ['0103060f1c212b2c3a3b', 'ca', 'cb']},
#   {'description': 'APC UPS',
#    'fingerprint': ['0603010f42430d2b3a3b2a020c',
#     '0603010f42430d2c2b3a3b2a020c']},
#   {'description': 'Tripplite UPS',
#    'fingerprint': ['0103060c0f1c2a2826172527131a']}],
#  'Video Conferencing': [{'description': 'Tandberg 1000',
#    'fingerprint': ['0103060c0f78f2']},
#   {'description': 'Polycom ViewStation',
#    'fingerprint': ['0601030c2c', '0601030c2c0f']},
#   {'description': 'Tandberg',
#    'fingerprint': ['010307', '01031c060c0f1a2af278']},
#   {'description': 'Polycom VSX 3000', 'fingerprint': ['0103060f0c2c']},
#   {'description': 'LifeSize Video Conferencing',
#    'fingerprint': ['011c02030f060c2a9d']}],
#  'BSD': [{'description': 'OpenBSD', 'fingerprint': ['011c030f060c']},
#   {'description': 'FreeBSD', 'fingerprint': ['011c0279030f060c']}],
#  'Misc': [{'description': 'Eye-Fi Wireless Memory Card',
#    'fingerprint': ['01031c06']}],
#  'Network Boot Agents': [{'description': 'Etherboot/Sun Blade 100',
#    'vendor_id': ['Etherboot-5.0', 'Etherboot-5.2', 'SUNW.Sun-Blade-100'],
#    'fingerprint': ['01030c2b']},
#   {'description': 'PXE',
#    'vendor_id': ['PXEClient:Arch:00000:UNDI:002001'],
#    'fingerprint': ['01020305060b0c0d0f1011122b363c438081828384858687',
#     '01030305060b0c0d0f1011122b363c438081828384858687',
#     '0102030405060b0c0d0f10111216171c28292a2b3233363a3b3c42438081828384858687',
#     '0102030405060c0d0f111216171c28292a2b3233363a3b3c4243618081828384858687',
#     '01032b363c438081828384858687']},
#   {'description': 'Novell Netware Client',
#    'fingerprint': ['4e4f55', '4e4f', '4f4e', '55', '5556', '555657', '64']},
#   {'description': 'Anaconda (RedHat) Installer',
#    'fingerprint': ['0103060f1c0c07092a30311a']},
#   {'description': 'Apple Netboot', 'fingerprint': ['01032b3c', '0103432b3c']},
#   {'description': 'Etherboot/gPXE', 'fingerprint': ['0103062b']},
#   {'description': 'Generic Intel PXE', 'fingerprint': ['01030c2c']}],
#  'CD-Based OSes': [{'description': 'Linspire',
#    'fingerprint': ['011c02030f060c2e2c']},
#   {'description': 'PHLAK', 'fingerprint': ['0103060f1c0c07092a3031']},
#   {'description': 'Knoppix', 'fingerprint': ['0103060f332c']}],
#  'Solaris': [{'description': 'OpenSolaris', 'fingerprint': ['0103060c0f1c2b']},
#   {'description': 'Solaris 8 (SunOS 5.8)',
#    'fingerprint': ['01020305060c0f131c2128294041']}],
#  'Projectors': [{'description': 'Epson Projectors',
#    'fingerprint': ['0603010f42430d2c']},
#   {'description': 'NEC Projectors',
#    'fingerprint': ['3201030c0f333a3b062a4546']}],
#  'Thin Clients': [{'description': 'Neoware e100 NeoLinux',
#    'fingerprint': ['0103060f1c0c07092a303189d3d4d5d6db']},
#   {'description': 'Neoware Capio Windows CE',
#    'fingerprint': ['0103060f2c2e2f89d7', '0103060f2c2e2f89d7e0e2']},
#   {'description': 'Generic Thin Client',
#    'fingerprint': ['0103060c0f111a1c28',
#     '0103060c0f111c',
#     '010306070c0f112b3c4243afcb']},
#   {'description': 'Wyse Technology thin client',
#    'fingerprint': ['011c030f060c022a30a1a2b8b9a3a4bcbdb5b6bebabb']}],
#  'Physical Security': [{'description': 'Paradox Card Access module',
#    'fingerprint': ['010306333a3b']}],
#  'Datacenter appliance': [{'description': 'VMware vCenter Server Appliance',
#    'fingerprint': ['3a3b011c7921030c770f0628292a1a117809072c2d2f',
#     '3a3b011c7921030c770f0628292a1a117809072c2d2e2f']}],
#  'Point of Sale devices': [{'description': 'Moneris HiSpeed 3100IP',
#    'fingerprint': ['0103060f4645']},
#   {'description': 'PCS Revenue Control Systems',
#    'fingerprint': ['0103062a0c0f1f212b']}]}

# %%
#adjust the result so it fit more with the task
listDictResult = []
for i in result.keys():
  tempDict = {"description": i, "os" : result[i]}
  listDictResult.append(tempDict)

# %%
#save to json file
with open("sample.json", "w") as outfile:
    json.dump({"class": listDictResult}, outfile, indent = 3)
